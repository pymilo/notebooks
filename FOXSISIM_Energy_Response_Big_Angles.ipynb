# %% [markdown]
# ### Creating a big shell, if the energy response works welll, the high energy photons should not appear on the detector.

# %% [markdown]
# # Playing the focal lengths of the FOXSI optics

# %%
from foxsisim.module import Module
from foxsisim.detector import Detector
from foxsisim.source import Source
from foxsisim.plotting import plot,scatterHist
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Creating spectrum

# %%
max_energy = 30.0
def spectrum(z):
        if (type(z) is not type([1])) and (type(z) is not type(np.array(1))):
            x = np.array([z])
        else:
            x = np.array(z)
        return np.piecewise(x, [x < 0, ((x < max_energy) & (x > 0)), (x >= max_energy)], [0, 1./max_energy, 0])
    
source_distance = -1e4 ##cm
source = Source(type='point', center=[0, 0, source_distance])
source.loadSpectrum(spectrum)
energies = np.arange(-10, 60, 0.1)
plt.plot(energies, source._spectrum(energies))
plt.xlabel('Energy [keV]')
plt.title('Source Spectrum')
plt.show()

# %% [markdown]
# # F = 200

# %%
module = Module(radii=[5.151,4.9],focal=200.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

# %%
plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %% [markdown]
# ## Pass and catch rays

# %%
from datetime import datetime
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))
# Out:
# Number of rays on Detector 32
# Time total: 164 seconds
# Time per ray (s): 0.1951219512195122

# %%
drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 190

# %%
module = Module(radii=[5.151,4.9],focal=190.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 28
# Time total: 194 seconds
# Time per ray (s): 0.14432989690721648

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 180

# %%
module = Module(radii=[5.151,4.9],focal=180.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 29
# Time total: 174 seconds
# Time per ray (s): 0.16666666666666666

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 170

# %%
module = Module(radii=[5.151,4.9],focal=170.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 27
# Time total: 223 seconds
# Time per ray (s): 0.1210762331838565

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 160

# %%
module = Module(radii=[5.151,4.9],focal=160.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 18
# Time total: 208 seconds
# Time per ray (s): 0.08653846153846154

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 150

# %%
module = Module(radii=[5.151,4.9],focal=150.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 11
# Time total: 192 seconds
# Time per ray (s): 0.057291666666666664

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 140

# %%
module = Module(radii=[5.151,4.9],focal=140.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 16
# Time total: 196 seconds
# Time per ray (s): 0.08163265306122448

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 130

# %%
module = Module(radii=[5.151,4.9],focal=130.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 15
# Time total: 176 seconds
# Time per ray (s): 0.08522727272727272

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 120

# %%
module = Module(radii=[5.151,4.9],focal=120.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 18
# Time total: 164 seconds
# Time per ray (s): 0.10975609756097561

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 110

# %%
module = Module(radii=[5.151,4.9],focal=110.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 5
# Time total: 152 seconds
# Time per ray (s): 0.03289473684210526

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 100

# %%
module = Module(radii=[5.151,4.9],focal=100.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 0
# Time total: 169 seconds
# Time per ray (s): 0.0

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6198: RuntimeWarning: invalid value encountered in true_divide
#   m = (m.astype(float) / db) / m.sum()

# %% [markdown]
# # Now increasing the Focal Lenght

# %% [markdown]
# # F = 250

# %%
module = Module(radii=[5.151,4.9],focal=250.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 32
# Time total: 196 seconds
# Time per ray (s): 0.16326530612244897

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 300

# %%
module = Module(radii=[5.151,4.9],focal=300.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 29
# Time total: 188 seconds
# Time per ray (s): 0.15425531914893617

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 400

# %%
module = Module(radii=[5.151,4.9],focal=400.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 50
# Time total: 183 seconds
# Time per ray (s): 0.273224043715847

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 500

# %%
module = Module(radii=[5.151,4.9],focal=500.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 53
# Time total: 160 seconds
# Time per ray (s): 0.33125

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # F = 1000

# %%
module = Module(radii=[5.151,4.9],focal=1000.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 64
# Time total: 123 seconds
# Time per ray (s): 0.5203252032520326

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()

# %% [markdown]
# # 1500

# %%
module = Module(radii=[5.151,4.9],focal=1500.0)
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)

plt.figure()
plt.hist([ray.energy for ray in rays], normed=True, label='generated rays')
plt.xlabel('Energy [keV]')
plt.title('Histogram generated rays')
plt.legend()
plt.show()

# %%
tstart = datetime.now()

# pass rays through module
module.passRays(rays, robust=True)
# catch rays at detector
detector.catchRays(rays)


rays_on_detector = len(detector.rays)
print('Number of rays on Detector ' + str(rays_on_detector))
print('Time total: ' + str((datetime.now() - tstart).seconds) + ' seconds')
print('Time per ray (s): ' + str(rays_on_detector / float((datetime.now() - tstart).seconds)))

drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()
# Out:
# Number of rays on Detector 80
# Time total: 81 seconds
# Time per ray (s): 0.9876543209876543

# %%
plt.figure()
plt.hist([ray.energy for ray in detector.rays], normed=True, label='rays on detector',color='r')
plt.xlabel('Energy [keV]')
plt.title('Histogram caught rays on detector')
plt.legend()
plt.show()
