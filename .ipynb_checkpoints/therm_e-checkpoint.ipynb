# %%
import numpy as np
from scipy.io import readsav
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_old = readsav('/Users/kamilobu/Desktop/FOXSI/FOXSI-3/Quiet_Sun/steven/foxsi2_thermal_limit_flux_old.dat')
data_new = readsav('/Users/kamilobu/Desktop/FOXSI/FOXSI-3/Quiet_Sun/steven/foxsi2_thermal_limit_flux.dat')

# %%
thermal_energy_old = np.transpose(data_old['thermal_energy'])
thermal_energy_new = np.transpose(data_new['thermal_energy'])

# %%
plt.semilogy(thermal_energy_old)

# %%
plt.semilogy(thermal_energy_new)

# %%
plt.semilogy(thermal_energy_old-thermal_energy_new)
