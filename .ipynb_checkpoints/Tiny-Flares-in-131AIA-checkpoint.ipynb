# %% [markdown]
# # AIA 131

# %%
from sunpy.map import MapCubed
from sunpy.map import Map
import glob
import astropy.units as u
from sunpy.time import parse_time
from matplotlib.patches import Rectangle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
data_dir = '/Volumes/500GB/AIA/'
str_indices = {'94':'', '131':'', '171':'', '193':'', '211':'', '304':'', '335':'', '1600':'', '1700':''}
file_list = {}
maps = {}
for key in str_indices:
    file_list.update({key: glob.glob(data_dir + '*' + key + '*.fits')})
    
these_files = file_list['131'][49:90]

maps = []

for f in these_files:
    maps.append(Map(f))

cubed = MapCubed(maps)

# %% [markdown]
# ## Full resolution

# %%
x_range = u.Quantity([-900, 0], 'arcsec')
y_range = u.Quantity([-700, 200], 'arcsec')
scubed = cubed.submap(x_range, y_range)
scubed[0].plot()
plt.colorbar()

# %% [markdown]
# ## Rebinning [15 pix]

# %%
sscubed = scubed.superpixel(u.Quantity([15 * u.pixel, 15 * u.pixel]))
sscubed[0].plot()
plt.colorbar()
# Out:
# [ 0.  0.] pix

# %% [markdown]
# # Steven's Flare

# %%
sscubed[0].plot(vmin=6000,vmax=15000)
ax = plt.gca()
xrect = 70
yrect = 58
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.std().plot(vmin=200,vmax=4000)
ax = plt.gca()
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.lightcurve(yrect,xrect).plot()

# %% [markdown]
# ## Second possible Tiny-Flare

# %%
sscubed[0].plot(vmin=6000,vmax=15000)
ax = plt.gca()
xrect = 49
yrect = 54
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.std().plot(vmin=200,vmax=4000)
ax = plt.gca()
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.lightcurve(yrect,xrect).plot()

# %% [markdown]
# ## Third Possible Tiny-Flare

# %%
sscubed[0].plot(vmin=1200,vmax=15000)
ax = plt.gca()
xrect = 50
yrect = 17
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.std().plot(vmin=200,vmax=4000)
ax = plt.gca()
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.lightcurve(yrect,xrect).plot()

# %% [markdown]
# ## Fourth possible Tiny-flare

# %%
sscubed[10].plot(vmin=4000,vmax=15000)
ax = plt.gca()
xrect = 59
yrect = 48
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.std().plot(vmin=200,vmax=4000)
ax = plt.gca()
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.lightcurve(yrect,xrect).plot()

# %% [markdown]
# ## Fifth possible Tiny Flare

# %%
sscubed[0].plot(vmin=5000,vmax=15000)
ax = plt.gca()
xrect = 61
yrect = 14
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.std().plot(vmin=200,vmax=4000)
ax = plt.gca()
ax.add_patch(Rectangle((xrect-0.5, yrect-0.5), 1, 1, fill=None,edgecolor='red',linewidth=1))
plt.colorbar()

# %%
sscubed.lightcurve(yrect,xrect).plot()
