# %%
from sunpy.map import MapCubed
from sunpy.map import Map
import glob
import astropy.units as u
from sunpy.time import parse_time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
data_dir = '/Volumes/500GB/AIA/'
str_indices = {'94':'', '131':'', '171':'', '193':'', '211':'', '304':'', '335':'', '1600':'', '1700':''}
file_list = {}
maps = {}
for key in str_indices:
    file_list.update({key: glob.glob(data_dir + '*' + key + '*.fits')})
    
these_files = file_list['94'][51:90]

maps = []

for f in these_files:
    maps.append(Map(f))

cubed = MapCubed(maps)

# %%
x_range = u.Quantity([-900, 0], 'arcsec')
y_range = u.Quantity([-700, 200], 'arcsec')

scubed = cubed.submap(x_range, y_range)

# %%
'''Uncomment to watch the movie'''
#b=tuple(scubed)
#a=Map(b,cube=True)
#%matplotlib
#a.plot()
##%matplotlib inline
# Out:
# 'Uncomment to watch the movie'

# %%
from matplotlib.patches import Rectangle
# %matplotlib inline
scubed.std().plot(vmin=1.5,vmax=5)
ax = plt.gca()
xrect = 750
yrect = 750
ax.add_patch(Rectangle((xrect, yrect), 50, 50, fill=None))
plt.colorbar()

# %%
sscubed = scubed.superpixel(u.Quantity([15 * u.pixel, 15 * u.pixel]))
# Out:
# [ 0.  0.] pix

# %%
sscubed.plot()
plt.colorbar()

# %%
sscubed.std().plot(vmin=32,vmax=100)
print(sscubed.dimensions)
ax = plt.gca()
xrect = 68
yrect = 50
ax.add_patch(Rectangle((xrect, yrect), 5, 5, fill=None,edgecolor='red',linewidth=2))
plt.colorbar()
# Out:
# (99, 100)

# %%
#sscubed.lightcurve(yrect,xrect).plot()
sscubed.lightcurve(50,2).plot()

# %%
sscubed[0].plot()

# %%
sscubed[0].data.shape
# Out:
# 100

# %%
type(sscubed[0].data)
# Out:
# numpy.ndarray

# %%
s=sscubed[0].data.shape
sscubed[0].data[:,:] = np.zeros(s)

# %%
sscubed[0].plot()
# Out:
# /Users/Kamilobu/anaconda/envs/ay250/lib/python3.5/site-packages/astropy/visualization/mpl_normalize.py:76: RuntimeWarning: invalid value encountered in true_divide
#   np.true_divide(values, self.vmax - self.vmin, out=values)
# /Users/Kamilobu/anaconda/envs/ay250/lib/python3.5/site-packages/matplotlib/colors.py:581: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)
