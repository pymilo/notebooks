# %% [markdown]
# # Download AIA data

# %%
import sunpy
from sunpy.net import vso
from astropy import units as u
client=vso.VSOClient()

# %%
result = client.query(
    vso.attrs.Time((2014, 12, 11, 19, 0, 0),
                   (2014, 12, 11, 20, 0, 0)),
    vso.attrs.Instrument('aia'),
    vso.attrs.Wave(94*u.AA,1700*u.AA))

# %%
res = client.get(result, path="/Volumes/500GB/AIA/{file}").wait()

# %%
len(result)
# Out:
# 2399

# %%
result.time_range
# Out:
# <bound method QueryResponse.time_range of <Table length=2399>
#    Start Time [1]       End Time [1]    Source Instrument   Type
#        str19               str19         str3     str3      str8
# ------------------- ------------------- ------ ---------- --------
# 2014-12-11 19:00:01 2014-12-11 19:00:02    SDO        AIA FULLDISK
# 2014-12-11 19:00:02 2014-12-11 19:00:03    SDO        AIA FULLDISK
# 2014-12-11 19:00:06 2014-12-11 19:00:07    SDO        AIA FULLDISK
# 2014-12-11 19:00:07 2014-12-11 19:00:08    SDO        AIA FULLDISK
# 2014-12-11 19:00:08 2014-12-11 19:00:09    SDO        AIA FULLDISK
# 2014-12-11 19:00:11 2014-12-11 19:00:12    SDO        AIA FULLDISK
# 2014-12-11 19:00:11 2014-12-11 19:00:12    SDO        AIA FULLDISK
# 2014-12-11 19:00:13 2014-12-11 19:00:14    SDO        AIA FULLDISK
# 2014-12-11 19:00:14 2014-12-11 19:00:15    SDO        AIA FULLDISK
# 2014-12-11 19:00:16 2014-12-11 19:00:17    SDO        AIA FULLDISK
#                 ...                 ...    ...        ...      ...
# 2014-12-11 19:59:47 2014-12-11 19:59:48    SDO        AIA FULLDISK
# 2014-12-11 19:59:47 2014-12-11 19:59:48    SDO        AIA FULLDISK
# 2014-12-11 19:59:49 2014-12-11 19:59:50    SDO        AIA FULLDISK
# 2014-12-11 19:59:50 2014-12-11 19:59:51    SDO        AIA FULLDISK
# 2014-12-11 19:59:52 2014-12-11 19:59:53    SDO        AIA FULLDISK
# 2014-12-11 19:59:54 2014-12-11 19:59:55    SDO        AIA FULLDISK
# 2014-12-11 19:59:55 2014-12-11 19:59:56    SDO        AIA FULLDISK
# 2014-12-11 19:59:56 2014-12-11 19:59:57    SDO        AIA FULLDISK
# 2014-12-11 19:59:59 2014-12-11 20:00:00    SDO        AIA FULLDISK
# 2014-12-11 19:59:59 2014-12-11 20:00:00    SDO        AIA FULLDISK>

# %% [markdown]
# # Testing Mapcubed

# %%
from sunpy.map import MapCubed
from sunpy.map import Map
import glob
import astropy.units as u
from sunpy.time import parse_time
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('image', interpolation='nearest')
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
data_dir = '/Volumes/500GB/AIA/'
str_indices = {'94':'', '131':'', '171':'', '193':'', '211':'', '304':'', '335':'', '1600':'', '1700':''}
file_list = {}
maps = {}

# %%
for key in str_indices:
    file_list.update({key: glob.glob(data_dir + '*' + key + '*.fits')})

# %%
these_files = file_list['1600'][0:10]
#print(these_files)

maps = []

for f in these_files:
    maps.append(Map(f))

cubed = MapCubed(maps)

# %%
x_range = u.Quantity([-450, 450], 'arcsec')
y_range = u.Quantity([-700, 200], 'arcsec')

scubed = cubed.submap(x_range, y_range)

# %%
scubed.mean().plot()
plt.colorbar()

# %%
scubed.std().plot()
plt.colorbar()

# %%
scubed.min().plot()
plt.colorbar()

# %%
scubed.max().plot()
plt.colorbar()

# %%
scubed.lightcurve(0.,0.)
# Out:
# SunPy MapCubed
# ---------
# Observatory:	 SDO/AIA
# Instrument:	 AIA 3
# Detector:	 AIA
# Measurement:	 1600.0 Angstrom
# Wavelength:	 1600.0 Angstrom
# Obs. Start:	 2014-12-11 19:25:52
# Obs. End:	 2014-12-11 19:29:28
# Num. of Frames:	 10
# Dimensions:	 [ 1477.  1477.]
# Scale:		 [ 0.609373  0.609373] arcsec / pix
# array([[[111, 108, 120, ..., 143, 143, 125],
#         [ 98, 105, 114, ..., 127, 151, 124],
#         [107, 109, 109, ..., 120, 141, 148],
#         ...,
#         [ 93,  99,  99, ..., 110, 108,  93],
#         [ 87,  89,  93, ...,  99, 103,  97],
#         [100,  91,  98, ..., 108, 115, 122]],
#
#        [[107, 107, 114, ..., 131, 141, 138],
#         [102, 102, 107, ..., 109, 120, 116],
#         [114, 107, 109, ..., 120, 127, 124],
#         ...,
#         [103, 107, 114, ..., 127, 124, 118],
#         [107,  96, 105, ..., 113, 119, 109],
#         [124, 107, 109, ..., 115, 121, 121]],
#
#        [[109, 107, 116, ..., 120, 137, 147],
#         [103,  99, 108, ..., 108, 106, 101],
#         [103,  98,  93, ..., 118, 118, 118],
#         ...,
#         [110, 115, 125, ..., 131, 140, 134],
#         [114, 114, 120, ..., 123, 130, 123],
#         [133, 124, 130, ..., 127, 130, 127]],
#
#        ...,
#        [[225, 229, 217, ..., 214, 217, 221],
#         [238, 230, 218, ..., 218, 230, 230],
#         [263, 255, 239, ..., 223, 235, 251],
#         ...,
#         [144, 116, 106, ...,  77,  90,  98],
#         [169, 141, 135, ...,  84, 103, 113],
#         [142, 142, 142, ..., 105, 126, 126]],
#
#        [[253, 262, 237, ..., 217, 225, 217],
#         [255, 255, 243, ..., 231, 235, 212],
#         [279, 266, 266, ..., 238, 246, 246],
#         ...,
#         [146, 130, 121, ...,  87,  95, 112],
#         [223, 176, 144, ...,  90, 109, 132],
#         [187, 177, 136, ..., 102, 121, 133]],
#
#        [[233, 237, 237, ..., 233, 233, 211],
#         [238, 238, 242, ..., 246, 242, 234],
#         [251, 251, 247, ..., 267, 263, 243],
#         ...,
#         [121, 124, 118, ...,  91,  98, 112],
#         [160, 156, 144, ...,  96, 107, 122],
#         [153, 159, 140, ..., 100, 106, 122]]], dtype=int16)
