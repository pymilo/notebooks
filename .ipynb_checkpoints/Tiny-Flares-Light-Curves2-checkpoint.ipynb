# %% [markdown]
# ### FOXSI Observation time:
#
# Data taken from the foxsi-science soft.

# %%
import seaborn as sns
from datetime import datetime, timedelta

#t0 = '11-Dec-2014 19:11:00.000'
t0 = datetime(2014,12,11,19,11,0)
t_end = timedelta(seconds=503.2)

ti = t0 
tf = t0 + t_end

# %%
print('T_init = ',t0)
print('T_end = ',t0 + t_end)
print('Delta t = ',tf - ti)
# Out:
# T_init =  2014-12-11 19:11:00
# T_end =  2014-12-11 19:19:23.200000
# Delta t =  0:08:23.200000

# %% [markdown]
# # Light-Curves

# %%
from sunpy.map import MapCubed
from sunpy.map import Map
import glob
import astropy.units as u
from sunpy.time import parse_time
from matplotlib.patches import Rectangle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
data_dir = '/Volumes/500GB/AIA/'
str_indices = {'94':'', '131':'', '171':'', '193':'', '211':'', '304':'', '335':'', '1600':'', '1700':''}
file_list = {}
maps = {}
for key in str_indices:
    file_list.update({key: glob.glob(data_dir + '*' + key + '*.fits')})

# %% [markdown]
# Location of Tiny-Flares:

# %%
xrect = [70, 49, 50, 59, 61]
yrect = [58, 54, 17, 48, 14]

# %% [markdown]
# ## AIA 094

# %%
these_files = file_list['94'][48:87]
maps = []
for f in these_files:
    maps.append(Map(f))
cubed = MapCubed(maps)
x_range = u.Quantity([-900, 0], 'arcsec')
y_range = u.Quantity([-700, 200], 'arcsec')
scubed = cubed.submap(x_range, y_range)
sscubed094 = scubed.superpixel(u.Quantity([15 * u.pixel, 15 * u.pixel]))
# Out:
# [ 0.  0.] pix

# %%
dat094=[]
for x,y in zip(xrect,yrect):
    dat094.append(sscubed094.lightcurve(y,x).data)

# %%
dat094[0]
# Out:
#                          58,70
# 2014-12-11 19:11:01.120   2633
# 2014-12-11 19:11:25.120   2602
# 2014-12-11 19:11:37.120   2679
# 2014-12-11 19:11:49.120   2567
# 2014-12-11 19:12:01.140   2605
# 2014-12-11 19:12:13.120   2670
# 2014-12-11 19:12:25.120   2682
# 2014-12-11 19:12:37.120   2616
# 2014-12-11 19:12:49.120   2628
# 2014-12-11 19:13:01.120   2645
# 2014-12-11 19:13:13.120   2600
# 2014-12-11 19:13:37.120   2576
# 2014-12-11 19:14:01.120   2571
# 2014-12-11 19:14:13.120   2606
# 2014-12-11 19:14:25.120   2633
# 2014-12-11 19:14:37.120   2571
# 2014-12-11 19:14:49.120   2521
# 2014-12-11 19:15:01.120   2552
# 2014-12-11 19:15:13.120   2561
# 2014-12-11 19:15:25.120   2600
# 2014-12-11 19:15:37.120   2610
# 2014-12-11 19:15:49.120   2536
# 2014-12-11 19:16:13.120   2411
# 2014-12-11 19:16:25.120   2511
# 2014-12-11 19:16:37.120   2597
# 2014-12-11 19:16:49.120   2499
# 2014-12-11 19:17:01.120   2457
# 2014-12-11 19:17:13.120   2404
# 2014-12-11 19:17:25.120   2446
# ...

# %% [markdown]
# ## AIA 131

# %%
these_files = file_list['131'][53:89]
maps = []
for f in these_files:
    maps.append(Map(f))
cubed = MapCubed(maps)
x_range = u.Quantity([-900, 0], 'arcsec')
y_range = u.Quantity([-700, 200], 'arcsec')
scubed = cubed.submap(x_range, y_range)
sscubed131 = scubed.superpixel(u.Quantity([15 * u.pixel, 15 * u.pixel]))
# Out:
# [ 0.  0.] pix

# %%
d
# 2014-12-11 19:15:19.130  17334
# 2014-12-11 19:15:31.130  17387
# 2014-12-11 19:15:43.120  17291
# 2014-12-11 19:15:55.120  17184
# 2014-12-11 19:16:07.120  16907
# 2014-12-11 19:16:19.130  16836
# 2014-12-11 19:16:31.130  16701
# 2014-12-11 19:16:43.130  16529
# 2014-12-11 19:16:55.120  16894
# 2014-12-11 19:17:19.130  16625
# 2014-12-11 19:17:31.130  16710
# ...

# %% [markdown]
# ## AIA 335

# %%
these_files = file_list['335'][52:89]
maps = []
for f in these_files:
    maps.append(Map(f))
cubed = MapCubed(maps)
x_range = u.Quantity([-900, 0], 'arcsec')
y_range = u.Quantity([-700, 200], 'arcsec')
scubed = cubed.submap(x_range, y_range)
sscubed335 = scubed.superpixel(u.Quantity([15 * u.pixel, 15 * u.pixel]))
# Out:
# [ 0.  0.] pix

# %%
dat335=[]
for x,y in zip(xrect,yrect):
    dat335.append(sscubed335.lightcurve(y,x).data)
dat335[0]
# Out:
#                          58,70
# 2014-12-11 19:11:02.620   3801
# 2014-12-11 19:11:14.620   3678
# 2014-12-11 19:11:26.620   3778
# 2014-12-11 19:11:38.630   3777
# 2014-12-11 19:11:50.630   3862
# 2014-12-11 19:12:02.620   3784
# 2014-12-11 19:12:14.620   3795
# 2014-12-11 19:12:26.620   3753
# 2014-12-11 19:12:38.630   3834
# 2014-12-11 19:12:50.620   3756
# 2014-12-11 19:13:02.620   3748
# 2014-12-11 19:13:14.620   3726
# 2014-12-11 19:13:26.620   3745
# 2014-12-11 19:13:38.630   3728
# 2014-12-11 19:13:50.620   3679
# 2014-12-11 19:14:02.630   3671
# 2014-12-11 19:14:14.620   3630
# 2014-12-11 19:14:26.620   3673
# 2014-12-11 19:14:38.630   3665
# 2014-12-11 19:14:50.620   3723
# 2014-12-11 19:15:02.630   3709
# 2014-12-11 19:15:14.620   3727
# 2014-12-11 19:15:26.620   3654
# 2014-12-11 19:15:38.630   3635
# 2014-12-11 19:15:50.620   3581
# 2014-12-11 19:16:02.620   3660
# 2014-12-11 19:16:14.630   3663
# 2014-12-11 19:16:26.620   3689
# 2014-12-11 19:16:38.630   3693
# ...

# %% [markdown]
# # Tiny-Flare1

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, figsize=(5, 10),sharex=True)
dat094[0].plot(ax=ax1, c='#479084')
ax1.legend(['AIA094$\AA$'])
dat131[0].plot(ax=ax2, c='#31c8c7')
ax2.legend(['AIA131$\AA$'])
dat171[0].plot(ax=ax3, c='#fecc4b')
ax3.legend(['AIA171$\AA$'])
dat193[0].plot(ax=ax4, c='#b9874d')
ax4.legend(['AIA193$\AA$'])
dat211[0].plot(ax=ax5, c='#d3b0b6')
ax5.legend(['AIA211$\AA$'])
dat304[0].plot(ax=ax6, c='#fd7822')
ax6.legend(['AIA304$\AA$'])
dat335[0].plot(ax=ax7, c='#326ea5')
ax7.legend(['AIA335$\AA$'])
plt.show()
#f.savefig('/Users/kamilobu/Desktop/tinyflare1.png')

# %% [markdown]
# # Tiny-Flare2

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, figsize=(5, 10),sharex=True)
dat094[1].plot(ax=ax1, c='#479084')
ax1.legend(['AIA094$\AA$'])
dat131[1].plot(ax=ax2, c='#31c8c7')
ax2.legend(['AIA131$\AA$'])
dat171[1].plot(ax=ax3, c='#fecc4b')
ax3.legend(['AIA171$\AA$'])
dat193[1].plot(ax=ax4, c='#b9874d')
ax4.legend(['AIA193$\AA$'])
dat211[1].plot(ax=ax5, c='#d3b0b6')
ax5.legend(['AIA211$\AA$'])
dat304[1].plot(ax=ax6, c='#fd7822')
ax6.legend(['AIA304$\AA$'])
dat335[1].plot(ax=ax7, c='#326ea5')
ax7.legend(['AIA335$\AA$'])
plt.show()
f.savefig('/Users/kamilobu/Desktop/tinyflare2.png')

# %% [markdown]
# # Tiny-Flare3

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, figsize=(5, 10),sharex=True)
dat094[2].plot(ax=ax1, c='#479084')
ax1.legend(['AIA094$\AA$'])
dat131[2].plot(ax=ax2, c='#31c8c7')
ax2.legend(['AIA131$\AA$'])
dat171[2].plot(ax=ax3, c='#fecc4b')
ax3.legend(['AIA171$\AA$'])
dat193[2].plot(ax=ax4, c='#b9874d')
ax4.legend(['AIA193$\AA$'])
dat211[2].plot(ax=ax5, c='#d3b0b6')
ax5.legend(['AIA211$\AA$'])
dat304[2].plot(ax=ax6, c='#fd7822')
ax6.legend(['AIA304$\AA$'])
dat335[2].plot(ax=ax7, c='#326ea5')
ax7.legend(['AIA335$\AA$'])
plt.show()
f.savefig('/Users/kamilobu/Desktop/tinyflare3.png')

# %% [markdown]
# # Tiny-Flare4

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, figsize=(5, 10),sharex=True)
dat094[3].plot(ax=ax1, c='#479084')
ax1.legend(['AIA094$\AA$'])
dat131[3].plot(ax=ax2, c='#31c8c7')
ax2.legend(['AIA131$\AA$'])
dat171[3].plot(ax=ax3, c='#fecc4b')
ax3.legend(['AIA171$\AA$'])
dat193[3].plot(ax=ax4, c='#b9874d')
ax4.legend(['AIA193$\AA$'])
dat211[3].plot(ax=ax5, c='#d3b0b6')
ax5.legend(['AIA211$\AA$'])
dat304[3].plot(ax=ax6, c='#fd7822')
ax6.legend(['AIA304$\AA$'])
dat335[3].plot(ax=ax7, c='#326ea5')
ax7.legend(['AIA335$\AA$'])
plt.show()
f.savefig('/Users/kamilobu/Desktop/tinyflare4.png')

# %% [markdown]
# # Tiny-Flare5

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, figsize=(5, 10),sharex=True)
dat094[4].plot(ax=ax1, c='#479084')
ax1.legend(['AIA094$\AA$'])
dat131[4].plot(ax=ax2, c='#31c8c7')
ax2.legend(['AIA131$\AA$'])
dat171[4].plot(ax=ax3, c='#fecc4b')
ax3.legend(['AIA171$\AA$'])
dat193[4].plot(ax=ax4, c='#b9874d')
ax4.legend(['AIA193$\AA$'])
dat211[4].plot(ax=ax5, c='#d3b0b6')
ax5.legend(['AIA211$\AA$'])
dat304[4].plot(ax=ax6, c='#fd7822')
ax6.legend(['AIA304$\AA$'])
dat335[4].plot(ax=ax7, c='#326ea5')
ax7.legend(['AIA335$\AA$'])
plt.show()
f.savefig('/Users/kamilobu/Desktop/tinyflare5.png')
