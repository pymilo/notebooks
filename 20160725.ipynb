# %%
import foxsisim
from foxsisim.module import Module
from foxsisim.detector import Detector
from foxsisim.source import Source
from foxsisim.plotting import scatterHist
import matplotlib.pyplot as plt
from foxsisim.plotting import plot
import numpy as np

# %%
module = Module(radii=[5.151,3.799],
                seglen=30.0,
                base=[0,0,0],
                focal=200,
                angles=None,
                conic=False,
                core_radius=2.856)#2.856

detector = Detector(width=3.96,#0.96 
                    height=3.96,#0.96
                    normal=[0,0,1],
                    center=[0,0,230.0],
                    reso =[128,128])
source_distance = -2187.5
offaxis_angle_arcmin = 1.0

source = Source(type='point',
                center=[ source_distance * np.sin(np.deg2rad(offaxis_angle_arcmin/60.0)) , 0.0 , source_distance ]
                )

#source = Source(type='atinf',          
#                center=[ source_distance * np.sin(np.deg2rad(offaxis_angle_arcmin/60.0)) , 0.0 , -10 ],
#                color=[0,1,1],
#                width=15,
#                height=15)
rays = source.generateRays(module.targetFront, 200)
module.passRays(rays, robust=True)
detector.catchRays(rays)
# Out:
# 0 ray bounce number 1
# [ 0.00800465  0.00728948  0.99994139]
# 0 ray bounce number 2
# None
# 0 ray killed by reflect
# 1 ray bounce number 1
# [-0.00303083 -0.01067877  0.99993839]
# 1 ray bounce number 2
# None
# 1 ray killed by reflect
# 2 ray bounce number 1
# [-0.01464406  0.02676702  0.99953443]
# 3 ray bounce number 1
# [-0.03003219  0.02820473  0.99915092]
# 4 ray bounce number 1
# [ 0.00892006  0.04007027  0.99915705]
# 5 ray bounce number 1
# [-0.02923834 -0.02925206  0.99914435]
# 6 ray bounce number 1
# [ 0.02023963 -0.03562738  0.99916017]
# 8 ray bounce number 1
# [ 0.01075158  0.00156991  0.99994097]
# 8 ray bounce number 2
# None
# 8 ray killed by reflect
# 9 ray bounce number 1
# [-0.01065391 -0.02845132  0.9995384 ]
# 12 ray bounce number 1
# [ 0.03038362  0.02731888  0.99916491]
# 15 ray bounce number 1
# [-0.03054626 -0.00242351  0.99953042]
# 16 ray bounce number 1
# [ 0.01305277  0.00723461  0.99988864]
# 16 ray bounce number 2
# None
# 16 ray killed by reflect
# 17 ray bounce number 1
# [ 0.0314851   0.02607768  0.99916397]
# 18 ray bounce number 1
# [-0.01737819 -0.03733287  0.99915177]
# 20 ray bounce number 1
# [ 0.00210159 -0.01079612  0.99993951]
# 20 ray bounce number 2
# None
# 20 ray killed by reflect
# 21 ray bounce number 1
# [-0.01059968  0.01106891  0.99988256]
# 21 ray bounce number 2
# None
# 21 ray killed by reflect
# 24 ray bounce number 1
# [ 0.02867344 -0.0292395   0.99916109]
# 27 ray bounce number 1
# [  4.06553602e-02   8.41190369e-05   9.99173226e-01]
# 30 ray bounce number 1
# [-0.01034145  0.00451219  0.99993635]
# 30 ray bounce number 2
# None
# 30 ray killed by reflect
# 31 ray bounce number 1
# [-0.02412957  0.01873782  0.99953322]
# 32 ray bounce number 1
# [ 0.02534749 -0.01632302  0.99954543]
# 36 ray bounce number 1
# [-0.04120315 -0.00126651  0.99914999]
# 36 ray bounce number 2
# None
# 36 ray killed by reflect
# 37 ray bounce number 1
# [-0.02703452 -0.01433093  0.99953177]
# 38 ray bounce number 1
# [-0.03480318 -0.0223896   0.99914336]
# 39 ray bounce number 1
# [ 0.01026432  0.00354263  0.99994105]
# 39 ray bounce number 2
# None
# 39 ray killed by reflect
# 40 ray bounce number 1
# [ 0.02415858 -0.03297203  0.99916425]
# 41 ray bounce number 1
# [ 0.02935141 -0.00641284  0.99954858]
# 41 ray bounce number 2
# None
# 41 ray killed by reflect
# 42 ray bounce number 1
# [-0.03748516 -0.01709575  0.99915094]
# 42 ray bounce number 2
# None
# 42 ray killed by reflect
# 43 ray bounce number 1
# [ 0.01989541  0.03588295  0.99915794]
# 45 ray bounce number 1
# [ 0.03008942 -0.02749521  0.99916897]
# 46 ray bounce number 1
# [-0.03297024  0.02505978  0.99914212]
# 49 ray bounce number 1
# [-0.02148443  0.02152802  0.99953737]
# 50 ray bounce number 1
# [-0.00872704 -0.00700964  0.99993735]
# 50 ray bounce number 2
# None
# 50 ray killed by reflect
# 52 ray bounce number 1
# [ 0.0302155   0.02766441  0.9991605 ]
# 54 ray bounce number 1
# [ 0.00860015 -0.01222671  0.99988827]
# 54 ray bounce number 2
# [ 0.01364064 -0.01965792  0.99971371]
# 54 ray bounce number 3
# None
# 54 ray killed by reflect
# 56 ray bounce number 1
# [ 0.01255454 -0.00787933  0.99989014]
# 56 ray bounce number 2
# None
# 56 ray killed by reflect
# 57 ray bounce number 1
# [ -1.54088514e-02  -9.77891607e-04   9.99880798e-01]
# 57 ray bounce number 2
# None
# 57 ray killed by reflect
# 58 ray bounce number 1
# [ 0.03229258 -0.02513482  0.99916236]
# 59 ray bounce number 1
# [-0.03992035 -0.01055265  0.99914714]
# 59 ray bounce number 2
# None
# 59 ray killed by reflect
# 63 ray bounce number 1
# [ 0.02969587  0.00390563  0.99955135]
# 65 ray bounce number 1
# [-0.0174134   0.03740419  0.99914849]
# 66 ray bounce number 1
# [ 0.02008405 -0.03554826  0.99916613]
# 66 ray bounce number 2
# None
# 66 ray killed by reflect
# 68 ray bounce number 1
# [ 0.02479133 -0.0324899   0.99916455]
# 69 ray bounce number 1
# [-0.04089598 -0.00621082  0.99914411]
# 69 ray bounce number 2
# None
# 69 ray killed by reflect
# 73 ray bounce number 1
# [  2.83366627e-04   4.10143894e-02   9.99158516e-01]
# 74 ray bounce number 1
# [-0.014687   -0.00448845  0.99988207]
# 74 ray bounce number 2
# None
# 74 ray killed by reflect
# 75 ray bounce number 1
# [ 0.03713621  0.01669278  0.99917078]
# 77 ray bounce number 1
# [-0.0405935   0.00845835  0.99913994]
# 78 ray bounce number 1
# [-0.02375967  0.0336894   0.99914989]
# 79 ray bounce number 1
# [ 0.01213476 -0.00857627  0.99988959]
# 79 ray bounce number 2
# None
# 79 ray killed by reflect
# 81 ray bounce number 1
# [-0.02794397 -0.03056163  0.99914219]
# 84 ray bounce number 1
# [ 0.0106496  -0.02829613  0.99954285]
# 86 ray bounce number 1
# [ 0.02613722 -0.03150187  0.99916189]
# 89 ray bounce number 1
# [-0.04104902  0.00571994  0.99914076]
# 89 ray bounce number 2
# None
# 89 ray killed by reflect
# 90 ray bounce number 1
# [ 0.01443308 -0.00216387  0.9998935 ]
# 91 ray bounce number 1
# [ 0.00922344 -0.01173437  0.99988861]
# 91 ray bounce number 2
# [ 0.0147009  -0.01894474  0.99971245]
# 91 ray bounce number 3
# None
# 91 ray killed by reflect
# 96 ray bounce number 1
# [ 0.00881222  0.01206112  0.99988843]
# 96 ray bounce number 2
# [ 0.01401037  0.0194338   0.99971298]
# 96 ray bounce number 3
# None
# 96 ray killed by reflect
# 97 ray bounce number 1
# [-0.00779749  0.01299696  0.99988513]
# 97 ray bounce number 2
# None
# 97 ray killed by reflect
# 98 ray bounce number 1
# [ 0.03763848  0.01598409  0.99916358]
# 99 ray bounce number 1
# [-0.0039784   0.04088585  0.9991559 ]
# 103 ray bounce number 1
# [-0.01164848 -0.00987496  0.99988339]
# 103 ray bounce number 2
# None
# 103 ray killed by reflect
# 104 ray bounce number 1
# [ -9.90035611e-04   1.50120592e-02   9.99886823e-01]
# 104 ray bounce number 2
# None
# 104 ray killed by reflect
# 105 ray bounce number 1
# [-0.0407022   0.00780153  0.99914086]
# 106 ray bounce number 1
# [-0.03890553  0.0136499   0.99914966]
# 107 ray bounce number 1
# [ 0.0127585   0.02745879  0.99954151]
# 108 ray bounce number 1
# [-0.02495678  0.03286897  0.99914803]
# 109 ray bounce number 1
# [-0.0025841  -0.03027454  0.99953828]
# 110 ray bounce number 1
# [ 0.01442759 -0.02660372  0.99954194]
# 111 ray bounce number 1
# [ 0.00361095  0.04096501  0.99915406]
# 112 ray bounce number 1
# [ 0.0403511   0.00588713  0.99916822]
# 112 ray bounce number 2
# None
# 112 ray killed by reflect
# 113 ray bounce number 1
# [ 0.0328938  -0.02439653  0.99916105]
# 114 ray bounce number 1
# [-0.00548666  0.01414663  0.99988488]
# 114 ray bounce number 2
# [-0.00879785  0.02221161  0.99971458]
# 115 ray bounce number 1
# [ 0.00894882 -0.04016575  0.99915296]
# 116 ray bounce number 1
# [ 0.00383387 -0.01462075  0.99988576]
# 116 ray bounce number 2
# [ 0.0058224  -0.02282642  0.99972249]
# 116 ray bounce number 3
# None
# 116 ray killed by reflect
# 117 ray bounce number 1
# [-0.0108059   0.01067294  0.99988465]
# 117 ray bounce number 2
# None
# 117 ray killed by reflect
# 118 ray bounce number 1
# [-0.01794866  0.03714256  0.99914878]
# 119 ray bounce number 1
# [ 0.0270873  -0.01296558  0.99954898]
# 120 ray bounce number 1
# [ 0.01305439  0.03877151  0.99916283]
# 121 ray bounce number 1
# [ 0.0341033   0.02228143  0.99916991]
# 122 ray bounce number 1
# [ 0.03975149  0.00885017  0.9991704 ]
# 125 ray bounce number 1
# [ 0.01863179 -0.03641821  0.99916293]
# 127 ray bounce number 1
# [ 0.02376319  0.03316742  0.99916727]
# 131 ray bounce number 1
# [-0.00258422  0.0410166   0.99915512]
# 133 ray bounce number 1
# [ -4.75145189e-04   1.48790840e-02   9.99889187e-01]
# 137 ray bounce number 1
# [ 0.01151429 -0.03937003  0.99915836]
# 138 ray bounce number 1
# [ 0.00737208  0.01295061  0.99988896]
# 138 ray bounce number 2
# None
# 138 ray killed by reflect
# 139 ray bounce number 1
# [-0.01123654  0.00141634  0.99993587]
# 139 ray bounce number 2
# None
# 139 ray killed by reflect
# 140 ray bounce number 1
# [ 0.02939796 -0.00586174  0.9995506 ]
# 145 ray bounce number 1
# [  8.26629150e-04   1.48657409e-02   9.99889157e-01]
# 145 ray bounce number 2
# None
# 145 ray killed by reflect
# 146 ray bounce number 1
# [  4.09697173e-04  -1.49771674e-02   9.99887752e-01]
# 146 ray bounce number 2
# None
# 146 ray killed by reflect
# 147 ray bounce number 1
# [-0.00839303  0.01281888  0.99988261]
# 147 ray bounce number 2
# [-0.01293635  0.01952137  0.99972575]
# 148 ray bounce number 1
# [ 0.00618711 -0.04067318  0.99915335]
# 150 ray bounce number 1
# [-0.01025768 -0.00475656  0.99993608]
# 150 ray bounce number 2
# None
# 150 ray killed by reflect
# 151 ray bounce number 1
# [ 0.01071049 -0.0011227   0.99994201]
# 151 ray bounce number 2
# None
# 151 ray killed by reflect
# 152 ray bounce number 1
# [-0.01420732  0.03859601  0.99915389]
# 156 ray bounce number 1
# [ 0.0103718   0.01036499  0.99989249]
# 156 ray bounce number 2
# None
# 156 ray killed by reflect
# 157 ray bounce number 1
# [-0.03033444 -0.00330031  0.99953436]
# 158 ray bounce number 1
# [ -3.32062656e-04   1.12159783e-02   9.99937044e-01]
# 158 ray bounce number 2
# [ -6.68244760e-04   1.72829422e-02   9.99850415e-01]
# 158 ray bounce number 3
# None
# 158 ray killed by reflect
# 159 ray bounce number 1
# [-0.02345469  0.03385411  0.99915153]
# 162 ray bounce number 1
# [ 0.01486145 -0.02615546  0.99954741]
# 164 ray bounce number 1
# [-0.00503214 -0.00994691  0.99993787]
# 164 ray bounce number 2
# None
# 164 ray killed by reflect
# 166 ray bounce number 1
# [-0.02547962  0.01667376  0.99953628]
# 166 ray bounce number 2
# None
# 166 ray killed by reflect
# 167 ray bounce number 1
# [ 0.01441889  0.0024434   0.99989306]
# 167 ray bounce number 2
# None
# 167 ray killed by reflect
# 168 ray bounce number 1
# [-0.02343069  0.03389618  0.99915067]
# 176 ray bounce number 1
# [ 0.00337019 -0.03014349  0.9995399 ]
# 177 ray bounce number 1
# [ 0.0139594   0.00466004  0.9998917 ]
# 177 ray bounce number 2
# None
# 177 ray killed by reflect
# 178 ray bounce number 1
# [-0.01298553 -0.0080178   0.99988354]
# 178 ray bounce number 2
# None
# 178 ray killed by reflect
# 179 ray bounce number 1
# [-0.01182992  0.0393349   0.99915605]
# 180 ray bounce number 1
# [-0.01301326 -0.03908089  0.99915131]
# 181 ray bounce number 1
# [-0.02118747 -0.02192123  0.99953517]
# 182 ray bounce number 1
# [-0.01280795 -0.00809569  0.9998852 ]
# 182 ray bounce number 2
# None
# 182 ray killed by reflect
# 183 ray bounce number 1
# [ 0.01278376  0.00763883  0.99988911]
# 183 ray bounce number 2
# None
# 183 ray killed by reflect
# 184 ray bounce number 1
# [ -7.10233777e-04  -3.03004137e-02   9.99540585e-01]
# 185 ray bounce number 1
# [ 0.0093241   0.01154344  0.9998899 ]
# 185 ray bounce number 2
# None
# 185 ray killed by reflect
# 186 ray bounce number 1
# [ 0.01442297  0.0023523   0.99989322]
# 187 ray bounce number 1
# [-0.01764385  0.03713564  0.99915446]
# 189 ray bounce number 1
# [-0.02373185 -0.03373357  0.99914906]
# 191 ray bounce number 1
# [ 0.00134629  0.04111136  0.99915366]
# 192 ray bounce number 1
# [-0.00992251 -0.03985585  0.99915617]
# 192 ray bounce number 2
# None
# 192 ray killed by reflect
# 194 ray bounce number 1
# [-0.04118746  0.00328737  0.99914603]
# 194 ray bounce number 2
# None
# 194 ray killed by reflect
# 195 ray bounce number 1
# [-0.01128559  0.00202323  0.99993427]
# 195 ray bounce number 2
# None
# 195 ray killed by reflect
# 197 ray bounce number 1
# [ -1.14859367e-02   2.39073419e-04   9.99934006e-01]
# 197 ray bounce number 2
# None
# 197 ray killed by reflect
# 198 ray bounce number 1
# [-0.0138975   0.02699132  0.99953906]
# 199 ray bounce number 1
# [-0.03549951  0.02114407  0.99914599]

# %%
from foxsisim.plotting import get3dAxes
fig2 = plt.figure(figsize=(5, 5))
axes2 = get3dAxes(fig2)
rays3=[ray for ray in rays if ray.bounces==2]
module.plot3D(axes2, rays3 ,'k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e4ccf40f3d41> in <module>()
#       3 axes2 = get3dAxes(fig2)
#       4 rays3=[ray for ray in rays if ray.bounces==2]
# ----> 5 module.plot3D(axes2, rays3 ,'k')
#       6 plt.show()
#
# TypeError: plot3D() takes at most 3 arguments (4 given)

# %% [markdown]
# check what is happening with the plot3D() in the foxsisim.plotting import get3dAxes module
