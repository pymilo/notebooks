# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
from foxsisim.module import Module
from foxsisim.detector import Detector
from foxsisim.source import Source
from foxsisim.plotting import scatterHist

# %%
module = Module()
detector = Detector()

source_distance = -1e15
offaxis_angle_arcmin = 0.0
aux=source_distance * np.sin(np.deg2rad(offaxis_angle_arcmin/60.0))

source = Source(type='point',
                center=[ 0.0 , aux , source_distance ],
                color=[0,1,1])
rays = source.generateRays(module.targetFront, 10)
module.passRays(rays, robust=True)
detector.catchRays(rays)
scatterHist(rays)
# Out:
# Module: passing  10  rays
# 0 ray bounce number 1
# [ 0.01258108  0.03260358  0.99938918]
# 0 ray bounce number 2
# None
# 0 ray killed by reflect
# 1 ray bounce number 1
# [ 0.02748012  0.02441707  0.9993241 ]
# 1 ray bounce number 2
# None
# 1 ray killed by reflect
# 2 ray bounce number 1
# [ 0.01753165  0.03446943  0.99925197]
# 2 ray bounce number 2
# None
# 2 ray killed by reflect
# 3 ray bounce number 1
# [-0.03309958 -0.00323761  0.99944681]
# 3 ray bounce number 2
# None
# 3 ray killed by reflect
# 4 ray bounce number 1
# [ 0.00842379  0.00749328  0.99993644]
# 4 ray bounce number 2
# None
# 4 ray killed by reflect
# 5 ray bounce number 1
# [ 0.03305313 -0.00324818  0.99944832]
# 5 ray bounce number 2
# None
# 5 ray killed by reflect
# 6 ray bounce number 1
# [ 0.03423857  0.0071114   0.99938839]
# 6 ray bounce number 2
# None
# 6 ray killed by reflect
# 7 ray bounce number 1
# [-0.03109142  0.00572731  0.99950014]
# 7 ray bounce number 2
# None
# 7 ray killed by reflect
# 8 ray bounce number 1
# [-0.00922275 -0.00797624  0.99992566]
# 8 ray bounce number 2
# None
# 8 ray killed by reflect
# 9 ray bounce number 1
# [-0.00541445 -0.01003695  0.99993497]
# 9 ray bounce number 2
# [-0.0112904 -0.0209294  0.9997172]

# %%
for ray in rays:
    print("ray number: %i" % (ray.num))
    print("ray %i bounces: %i" % (ray.num, ray.bounces) )
    print(ray.hist)
    print("-----------------------")
# Out:
# ray number: 0
# ray 0 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([  3.10063797,   3.41160003,  32.79777658]), array([  3.10063797,   3.41160003,  32.79777658])]
# -----------------------
# ray number: 1
# ray 1 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([ -4.03108351,   1.43861497,  16.56677082]), array([ -3.77741149,   1.34808438,  42.58649559]), array([ -8.76188011e-13,   3.03845837e-12,   2.30000000e+02])]
# -----------------------
# ray number: 2
# ray 2 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([ -4.05295266,  -3.06432827,  33.6216149 ]), array([ -3.6754904 ,  -2.77893923,  45.84831221])]
# -----------------------
# ray number: 3
# ray 3 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([ -2.05715093,  -4.66046043,  32.93448833]), array([ -2.05715093,  -4.66046043,  32.93448833])]
# -----------------------
# ray number: 4
# ray 4 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([ -3.47439181,   1.97144063,  30.3504202 ]), array([ -3.14114302,   1.78234848,  43.1183799 ])]
# -----------------------
# ray number: 5
# ray 5 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([  2.97490858,   3.03596284,  22.25689427]), array([  2.97490858,   3.03596284,  22.25689427])]
# -----------------------
# ray number: 6
# ray 6 bounces: 3
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([-1.13403547, -4.90475037,  7.79487655]), array([ -1.02073341,  -4.41471428,  49.98360033]), array([ -1.02073341,  -4.41471428,  49.98360033])]
# -----------------------
# ray number: 7
# ray 7 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([  3.58421539,   1.77455214,  30.03637725]), array([  3.58421539,   1.77455214,  30.03637725])]
# -----------------------
# ray number: 8
# ray 8 bounces: 2
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([  3.01154753,  -3.19106537,  32.48274098]), array([  2.72710515,  -2.88966743,  44.94322014])]
# -----------------------
# ray number: 9
# ray 9 bounces: 3
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]), array([-4.08741823,  0.36848742,  8.92809819]), array([ -3.6978708 ,   0.33336909,  49.06175882]), array([ -3.6978708 ,   0.33336909,  49.06175882])]
# -----------------------

# %%
raypath = np.array([ray.hist for ray in rays])

# %%
raypath[0]
# Out:
# [array([  0.00000000e+00,  -0.00000000e+00,  -1.00000000e+15]),
#  array([  3.10063797,   3.41160003,  32.79777658]),
#  array([  3.10063797,   3.41160003,  32.79777658])]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# %matplotlib notebook
#soa =np.array( [ [0,0,1,1,-2,0], [0,0,2,1,1,0],[0,0,3,2,1,0],[0,0,4,0.5,0.7,0]]) 
soa =np.array( [ [0,0,0,1,1,1],[0,0,0,2,-2,-3] ] )

X,Y,Z,U,V,W = zip(*soa)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X,Y,Z,U,V,W,pivot="tail")
ax.set_xlim([-2,2])
ax.set_ylim([-2,2])
ax.set_zlim([-2,2])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
X,Y,Z
# Out:
# ((0,), (0,), (0,))

# %%
type(soa)
# Out:
# numpy.ndarray

# %%
type()
# Out:
# --------------------------------------------------
# TypeError        Traceback (most recent call last)
# <ipython-input-8-f3cf8f8eb46e> in <module>()
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
ax.quiver?
