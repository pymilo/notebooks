# %%
from foxsisim.module import Module
from foxsisim.detector import Detector
from foxsisim.source import Source
from foxsisim.plotting import scatterHist
from foxsisim.plotting import plot
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
if __name__ == '__main__':
    # create module of 7 shells
    module = Module(radii=[5.151,4.9, 4.659, 4.429, 4.21, 4.0,3.799],
#    module = Module(radii=[5.151, 4.9, 4.659, 4.429, 4.21, 4.0, 3.799],
                    seglen=30.0,
                    base=[0,0,0],
                    focal=200,
                    angles=None,
                    conic=False)

    detector = Detector(width=20.96,#0.96
                        height=20.96,#0.96
                        normal=[0,0,1],
                        #center=[0,0,200.0+30.0],
                        center=[0,0,230.0],
                        reso =[128,128])

# %%
    source_distance = -1e15
    offaxis_angle_arcmin = 0.0
    aux=source_distance * np.sin(np.deg2rad(offaxis_angle_arcmin/60.0))

#    source = Source(width=.28,   # 0.28 cm
#                 height=.28,     # 0.28 cm
#                 type='nonpoint',
#                 center=[ 0.0 , aux , source_distance ],
#                 color=[0,1,1])
    
    source = Source(type='point',
                center=[ 0.0 , aux , source_distance ],
                color=[0,1,1])

#    source = Source(center=[0, 0, -10000],
#                 width=10.302,  # 2*5.151 (max radius of default module)
#                 height=10.302,
#                 normal=[0, 0, 1],
#                 type='atinf',
#                 color=[1, 1, 1],
#                 pixels=None,
#                 spectrum=None)

    rays = source.generateRays(module.targetFront, 100)
    module.passRays(rays, robust=True)
    detector.catchRays(rays)
# Out:
# 0 ray bounce number 1
# [-0.03156281  0.0018623   0.99950004]
# 0 ray bounce number 2
# None
# 0 ray killed by reflect
# 1 ray bounce number 1
# [  8.96585826e-04   9.83871502e-03   9.99951197e-01]
# 1 ray bounce number 2
# [ 0.00183654  0.02015335  0.99979521]
# 2 ray bounce number 1
# [-0.0094849   0.00726989  0.99992859]
# 2 ray bounce number 2
# [-0.01992195  0.01526957  0.99968493]
# 2 ray bounce number 3
# None
# 2 ray killed by reflect
# 3 ray bounce number 1
# [ 0.00889258 -0.00632637  0.99994045]
# 3 ray bounce number 2
# [ 0.01829981 -0.01301888  0.99974778]
# 3 ray bounce number 3
# None
# 3 ray killed by reflect
# 4 ray bounce number 1
# [-0.00691512 -0.00757042  0.99994743]
# 4 ray bounce number 2
# [-0.01456721 -0.01594764  0.99976671]
# 4 ray bounce number 3
# None
# 4 ray killed by reflect
# 5 ray bounce number 1
# [ -1.02813669e-02   3.22070309e-04   9.99947093e-01]
# 5 ray bounce number 2
# [ -2.15192601e-02   6.74104409e-04   9.99768207e-01]
# 5 ray bounce number 3
# None
# 5 ray killed by reflect
# 6 ray bounce number 1
# [ 0.00954811 -0.00621425  0.99993511]
# 6 ray bounce number 2
# None
# 6 ray killed by reflect
# 7 ray bounce number 1
# [ 0.01008986  0.00168329  0.99994768]
# 7 ray bounce number 2
# [ 0.02135485  0.00356264  0.99976561]
# 7 ray bounce number 3
# None
# 7 ray killed by reflect
# 8 ray bounce number 1
# [-0.01029945 -0.02988227  0.99950036]
# 8 ray bounce number 2
# None
# 8 ray killed by reflect
# 9 ray bounce number 1
# [-0.03442106  0.00601935  0.99938929]
# 9 ray bounce number 2
# None
# 9 ray killed by reflect
# 10 ray bounce number 1
# [ 0.00375252 -0.01085023  0.99993409]
# 10 ray bounce number 2
# [ 0.00772088 -0.02232452  0.99972096]
# 11 ray bounce number 1
# [-0.01235196  0.00276151  0.9999199 ]
# 11 ray bounce number 2
# [-0.02555766  0.00571388  0.99965702]
# 12 ray bounce number 1
# [-0.0025271  -0.01134984  0.9999324 ]
# 12 ray bounce number 2
# [-0.00506897 -0.02276596  0.99972797]
# 13 ray bounce number 1
# [ 0.01036279  0.00641476  0.99992573]
# 13 ray bounce number 2
# None
# 13 ray killed by reflect
# 14 ray bounce number 1
# [-0.01006427 -0.00647806  0.99992837]
# 14 ray bounce number 2
# None
# 14 ray killed by reflect
# 15 ray bounce number 1
# [-0.02837522  0.02045978  0.99938793]
# 15 ray bounce number 2
# None
# 15 ray killed by reflect
# 16 ray bounce number 1
# [ 0.0072421   0.03796443  0.99925285]
# 16 ray bounce number 2
# None
# 16 ray killed by reflect
# 17 ray bounce number 1
# [ 0.01020334  0.00629346  0.99992814]
# 17 ray bounce number 2
# [ 0.02129658  0.01313581  0.9996869 ]
# 18 ray bounce number 1
# [-0.00259154 -0.00945744  0.99995192]
# 18 ray bounce number 2
# [-0.0053882  -0.01966344  0.99979214]
# 19 ray bounce number 1
# [-0.00705495 -0.00990432  0.99992606]
# 19 ray bounce number 2
# [-0.01431178 -0.02009206  0.99969569]
# 20 ray bounce number 1
# [ 0.00961027 -0.00466054  0.99994296]
# 20 ray bounce number 2
# [ 0.02064743 -0.01001307  0.99973668]
# 21 ray bounce number 1
# [-0.00567455  0.00973839  0.99993648]
# 21 ray bounce number 2
# [-0.01211402  0.02078951  0.99971048]
# 22 ray bounce number 1
# [ -9.97672527e-03   6.07999677e-04   9.99950046e-01]
# 22 ray bounce number 2
# None
# 22 ray killed by reflect
# 23 ray bounce number 1
# [-0.03363985 -0.01900876  0.99925323]
# 23 ray bounce number 2
# None
# 23 ray killed by reflect
# 24 ray bounce number 1
# [ 0.00656008 -0.01077063  0.99992048]
# 24 ray bounce number 2
# None
# 24 ray killed by reflect
# 25 ray bounce number 1
# [-0.00445009 -0.01136592  0.9999255 ]
# 25 ray bounce number 2
# [-0.00895969 -0.02288384  0.99969798]
# 25 ray bounce number 3
# None
# 25 ray killed by reflect
# 26 ray bounce number 1
# [-0.00526654  0.00951348  0.99994088]
# 26 ray bounce number 2
# None
# 26 ray killed by reflect
# 27 ray bounce number 1
# [-0.02999183 -0.00120773  0.99954941]
# 27 ray bounce number 2
# None
# 27 ray killed by reflect
# 28 ray bounce number 1
# [ 0.03110564 -0.00550589  0.99950094]
# 28 ray bounce number 2
# None
# 28 ray killed by reflect
# 29 ray bounce number 1
# [-0.03773153  0.0083448   0.99925307]
# 29 ray bounce number 2
# None
# 29 ray killed by reflect
# 30 ray bounce number 1
# [-0.02243248  0.02683025  0.99938827]
# 30 ray bounce number 2
# None
# 30 ray killed by reflect
# 31 ray bounce number 1
# [ 0.00155585  0.03157471  0.99950018]
# 31 ray bounce number 2
# None
# 31 ray killed by reflect
# 32 ray bounce number 1
# [ 0.00758993  0.00614673  0.9999523 ]
# 32 ray bounce number 2
# [ 0.01590795  0.01288312  0.99979046]
# 32 ray bounce number 3
# None
# 32 ray killed by reflect
# 33 ray bounce number 1
# [-0.01102391 -0.00286388  0.99993513]
# 33 ray bounce number 2
# [-0.02304558 -0.00598697  0.99971649]
# 34 ray bounce number 1
# [ 0.00857549  0.00818148  0.99992976]
# 34 ray bounce number 2
# [ 0.01831171  0.01747035  0.99967968]
# 34 ray bounce number 3
# None
# 34 ray killed by reflect
# 35 ray bounce number 1
# [ -5.16179115e-04   1.08817149e-02   9.99940659e-01]
# 35 ray bounce number 2
# [-0.00106602  0.02247296  0.99974688]
# 35 ray bounce number 3
# None
# 35 ray killed by reflect
# 36 ray bounce number 1
# [ 0.00733964  0.00818157  0.99993959]
# 36 ray bounce number 2
# None
# 36 ray killed by reflect
# 37 ray bounce number 1
# [ 0.0123099  -0.00294957  0.99991988]
# 37 ray bounce number 2
# None
# 37 ray killed by reflect
# 38 ray bounce number 1
# [ 0.01985732 -0.02247769  0.99955012]
# 38 ray bounce number 2
# None
# 38 ray killed by reflect
# 39 ray bounce number 1
# [-0.0102313  -0.00391899  0.99993998]
# 39 ray bounce number 2
# None
# 39 ray killed by reflect
# 40 ray bounce number 1
# [ 0.00969226 -0.00582745  0.99993605]
# 40 ray bounce number 2
# [ 0.02055153 -0.01235657  0.99971243]
# 40 ray bounce number 3
# None
# 40 ray killed by reflect
# 41 ray bounce number 1
# [ -1.18380408e-02   1.96386566e-04   9.99929909e-01]
# 41 ray bounce number 2
# [ -2.53321066e-02   4.20245674e-04   9.99679002e-01]
# 41 ray bounce number 3
# None
# 41 ray killed by reflect
# 42 ray bounce number 1
# [ -1.19846203e-02  -7.15814508e-04   9.99927926e-01]
# 42 ray bounce number 2
# [-0.02494028 -0.00148963  0.99968783]
# 43 ray bounce number 1
# [-0.0094955  -0.00426574  0.99994582]
# 43 ray bounce number 2
# None
# 43 ray killed by reflect
# 44 ray bounce number 1
# [-0.00965636  0.00463754  0.99994262]
# 44 ray bounce number 2
# [-0.02062459  0.00990512  0.99973822]
# 44 ray bounce number 3
# None
# 44 ray killed by reflect
# 45 ray bounce number 1
# [ 0.00465024  0.0084929   0.99995312]
# 45 ray bounce number 2
# [ 0.00991656  0.01811096  0.9997868 ]
# 46 ray bounce number 1
# [-0.00340278  0.01236831  0.99991772]
# 46 ray bounce number 2
# [-0.00685435  0.02491396  0.9996661 ]
# 46 ray bounce number 3
# None
# 46 ray killed by reflect
# 47 ray bounce number 1
# [-0.00979057 -0.0046157   0.99994142]
# 47 ray bounce number 2
# [-0.02048152 -0.00965588  0.9997436 ]
# 48 ray bounce number 1
# [ 0.00333829  0.01162975  0.9999268 ]
# 48 ray bounce number 2
# [ 0.00684021  0.02382958  0.99969263]
# 48 ray bounce number 3
# None
# 48 ray killed by reflect
# 49 ray bounce number 1
# [ 0.0064683   0.00852871  0.99994271]
# 49 ray bounce number 2
# [ 0.01383636  0.01824379  0.99973783]
# 49 ray bounce number 3
# None
# 49 ray killed by reflect
# 50 ray bounce number 1
# [ 0.01007761 -0.00379671  0.99994201]
# 50 ray bounce number 2
# [ 0.0212977  -0.00802384  0.99974098]
# 51 ray bounce number 1
# [-0.00498261 -0.01107991  0.9999262 ]
# 51 ray bounce number 2
# None
# 51 ray killed by reflect
# 52 ray bounce number 1
# [-0.01061515 -0.00168312  0.99994224]
# 52 ray bounce number 2
# [-0.02252283 -0.00357118  0.99973995]
# 52 ray bounce number 3
# None
# 52 ray killed by reflect
# 53 ray bounce number 1
# [ 0.02076161  0.0303425   0.99932392]
# 53 ray bounce number 2
# None
# 53 ray killed by reflect
# 54 ray bounce number 1
# [ 0.00962638  0.00209363  0.99995147]
# 54 ray bounce number 2
# [ 0.01983089  0.004313    0.99979405]
# 55 ray bounce number 1
# [ 0.0233113  -0.02131295  0.99950105]
# 55 ray bounce number 2
# None
# 55 ray killed by reflect
# 56 ray bounce number 1
# [-0.03768581  0.00867879  0.99925195]
# 56 ray bounce number 2
# None
# 56 ray killed by reflect
# 57 ray bounce number 1
# [  1.20015476e-02  -6.18103596e-04   9.99927788e-01]
# 57 ray bounce number 2
# [ 0.02492783 -0.00128383  0.99968843]
# 58 ray bounce number 1
# [-0.00877947 -0.00896887  0.99992124]
# 58 ray bounce number 2
# [-0.01847446 -0.01887301  0.99965119]
# 59 ray bounce number 1
# [-0.00690992  0.03804867  0.999252  ]
# 59 ray bounce number 2
# None
# 59 ray killed by reflect
# 60 ray bounce number 1
# [-0.00802508  0.00665801  0.99994563]
# 60 ray bounce number 2
# None
# 60 ray killed by reflect
# 61 ray bounce number 1
# [ -9.69482829e-03   4.36614929e-04   9.99952909e-01]
# 61 ray bounce number 2
# [ -2.05804991e-02   9.26860476e-04   9.99787769e-01]
# 61 ray bounce number 3
# None
# 61 ray killed by reflect
# 62 ray bounce number 1
# [-0.03522463  0.01054245  0.99932381]
# 62 ray bounce number 2
# None
# 62 ray killed by reflect
# 63 ray bounce number 1
# [ 0.00420746  0.01214749  0.99991736]
# 63 ray bounce number 2
# [ 0.00843882  0.024364    0.99966754]
# 63 ray bounce number 3
# None
# 63 ray killed by reflect
# 64 ray bounce number 1
# [-0.02648816 -0.02815164  0.99925265]
# 64 ray bounce number 2
# None
# 64 ray killed by reflect
# 65 ray bounce number 1
# [-0.02294884 -0.01937758  0.99954883]
# 65 ray bounce number 2
# None
# 65 ray killed by reflect
# 66 ray bounce number 1
# [-0.01133516  0.00379589  0.99992855]
# 66 ray bounce number 2
# None
# 66 ray killed by reflect
# 67 ray bounce number 1
# [-0.01061055  0.00388952  0.99993614]
# 67 ray bounce number 2
# None
# 67 ray killed by reflect
# 68 ray bounce number 1
# [-0.02718482  0.02745876  0.99925322]
# 68 ray bounce number 2
# None
# 68 ray killed by reflect
# 69 ray bounce number 1
# [-0.0107333  -0.0021506   0.99994008]
# 69 ray bounce number 2
# [-0.02195362 -0.00439879  0.99974931]
# 69 ray bounce number 3
# None
# 69 ray killed by reflect
# 70 ray bounce number 1
# [-0.02304607  0.02629912  0.99938843]
# 70 ray bounce number 2
# None
# 70 ray killed by reflect
# 71 ray bounce number 1
# [ 0.00480256  0.01110203  0.99992684]
# 71 ray bounce number 2
# [ 0.00984563  0.02276002  0.99969248]
# 71 ray bounce number 3
# None
# 71 ray killed by reflect
# 72 ray bounce number 1
# [-0.01179118 -0.0010037   0.99992998]
# 72 ray bounce number 2
# [-0.02525676 -0.00214993  0.99967869]
# 72 ray bounce number 3
# None
# 72 ray killed by reflect
# 73 ray bounce number 1
# [ 0.01008205  0.0065195   0.99992792]
# 73 ray bounce number 2
# [ 0.02097981  0.01356647  0.99968785]
# 73 ray bounce number 3
# None
# 73 ray killed by reflect
# 74 ray bounce number 1
# [-0.02910274  0.01228935  0.99950088]
# 74 ray bounce number 2
# None
# 74 ray killed by reflect
# 75 ray bounce number 1
# [ 0.00590854  0.01058728  0.9999265 ]
# 75 ray bounce number 2
# [ 0.01205679  0.0216041   0.9996939 ]
# 75 ray bounce number 3
# None
# 75 ray killed by reflect
# 76 ray bounce number 1
# [ 0.02567487 -0.02628295  0.99932478]
# 76 ray bounce number 2
# None
# 76 ray killed by reflect
# 77 ray bounce number 1
# [-0.00580008 -0.03107083  0.99950036]
# 77 ray bounce number 2
# None
# 77 ray killed by reflect
# 78 ray bounce number 1
# [-0.00693826  0.00763618  0.99994677]
# 78 ray bounce number 2
# [-0.01443465  0.01588664  0.9997696 ]
# 78 ray bounce number 3
# None
# 78 ray killed by reflect
# 79 ray bounce number 1
# [-0.00757058  0.00802743  0.99993912]
# 79 ray bounce number 2
# [-0.01523993  0.0161596   0.99975328]
# 79 ray bounce number 3
# None
# 79 ray killed by reflect
# 80 ray bounce number 1
# [-0.00378016 -0.01026101  0.99994021]
# 80 ray bounce number 2
# None
# 80 ray killed by reflect
# 81 ray bounce number 1
# [ 0.00889519  0.00706293  0.99993549]
# 81 ray bounce number 2
# None
# 81 ray killed by reflect
# 82 ray bounce number 1
# [ 0.00262863  0.01180735  0.99992684]
# 82 ray bounce number 2
# [ 0.00538876  0.02420539  0.99969248]
# 83 ray bounce number 1
# [-0.01023681 -0.00229152  0.99994498]
# 83 ray bounce number 2
# [-0.02060186 -0.00461175  0.99977712]
# 84 ray bounce number 1
# [-0.00176171 -0.03156852  0.99950004]
# 84 ray bounce number 2
# None
# 84 ray killed by reflect
# 85 ray bounce number 1
# [-0.00265058 -0.00986886  0.99994779]
# 85 ray bounce number 2
# [-0.00562162 -0.02093086  0.99976512]
# 85 ray bounce number 3
# None
# 85 ray killed by reflect
# 86 ray bounce number 1
# [-0.0115076  -0.00137486  0.99993284]
# 86 ray bounce number 2
# None
# 86 ray killed by reflect
# 87 ray bounce number 1
# [-0.00395702 -0.01001295  0.99994204]
# 87 ray bounce number 2
# [-0.00836668 -0.02117126  0.99974085]
# 88 ray bounce number 1
# [-0.00415767  0.00950803  0.99994615]
# 88 ray bounce number 2
# None
# 88 ray killed by reflect
# 89 ray bounce number 1
# [  1.09768209e-02  -4.44076123e-04   9.99939654e-01]
# 89 ray bounce number 2
# None
# 89 ray killed by reflect
# 90 ray bounce number 1
# [-0.0081908   0.00890151  0.99992683]
# 90 ray bounce number 2
# [-0.01679104  0.01824799  0.99969249]
# 91 ray bounce number 1
# [-0.03114925  0.00512473  0.99950161]
# 91 ray bounce number 2
# None
# 91 ray killed by reflect
# 92 ray bounce number 1
# [-0.00683694  0.00713356  0.99995118]
# 92 ray bounce number 2
# [-0.01400068  0.01460812  0.99979527]
# 92 ray bounce number 3
# None
# 92 ray killed by reflect
# 93 ray bounce number 1
# [ 0.01110229  0.00250696  0.99993523]
# 93 ray bounce number 2
# [ 0.02324217  0.00524822  0.99971609]
# 94 ray bounce number 1
# [ 0.01185073  0.03480403  0.99932389]
# 94 ray bounce number 2
# None
# 94 ray killed by reflect
# 95 ray bounce number 1
# [-0.01141667 -0.00386769  0.99992735]
# 95 ray bounce number 2
# [-0.02356938 -0.00798473  0.99969032]
# 96 ray bounce number 1
# [ 0.00941276  0.00452965  0.99994544]
# 96 ray bounce number 2
# [ 0.0191041   0.00919336  0.99977523]
# 96 ray bounce number 3
# None
# 96 ray killed by reflect
# 97 ray bounce number 1
# [ 0.00467888 -0.00905717  0.99994804]
# 97 ray bounce number 2
# [ 0.00997077 -0.01930097  0.999764  ]
# 98 ray bounce number 1
# [ 0.00304744  0.00997457  0.99994561]
# 98 ray bounce number 2
# None
# 98 ray killed by reflect
# 99 ray bounce number 1
# [-0.00715729 -0.00896208  0.99993422]
# 99 ray bounce number 2
# [-0.01475569 -0.01847652  0.9997204 ]
# 99 ray bounce number 3
# None
# 99 ray killed by reflect

# %%
    scatterHist(rays)

# %%
    plot(detector)
    plt.show()
