# %% [markdown]
# # Scatter Plot: Single Bounces in Red and Double Bounces in Green

# %% [markdown]
# Legitimate rays that reach the focal plane after one or two bounces have a z-component = 230. as expected. The color coding of these rays needs to be check. Nevertheless, rays which destination has a z-component of **zero** should not rech the focal plane, but they are still plot when we use *Scattering*.

# %%
from foxsisim.module import Module
from foxsisim.detector import Detector
from foxsisim.source import Source
from foxsisim.plotting import scatterHist,plot
import numpy as np
import matplotlib.pylab as plt

# %%
source_distance = -2000
source = Source(type='point', center=[0, 0, source_distance])
module = Module()
detector = Detector(width=8, 
                    height=8,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])

rays = source.generateRays(module.targetFront, 500)
module.passRays(rays, robust=True)
detector.catchRays(rays)

# %%
drays = [ray for ray in rays if ray.des[2]==230.0]
scatterHist(drays)
plt.show()

# %%
[ray.des for ray in rays]
# Out:
# [array([  6.45244505e-02,  -4.28720711e-01,   2.30000000e+02]),
#  array([ 0.,  0.,  0.]),
#  array([   1.02770532,    1.30922548,  230.        ]),
#  array([   1.36921961,   -0.50451371,  230.        ]),
#  array([   1.32858593,    0.67010694,  230.        ]),
#  array([  -0.7015478 ,    1.79261158,  230.        ]),
#  array([  -0.79993498,   -1.22862037,  230.        ]),
#  array([  -1.82122114,   -0.60478176,  230.        ]),
#  array([  -1.48804635,   -0.61892314,  230.        ]),
#  array([ 0.,  0.,  0.]),
#  array([ -1.86130894e-01,  -1.72214098e+00,   2.30000000e+02]),
#  array([  -1.42074828,   -0.53514559,  230.        ]),
#  array([  3.67351344e-01,  -1.39375117e-01,   2.30000000e+02]),
#  array([   0.38513625,    0.23772621,  230.        ]),
#  array([  -1.17605309,   -1.56336217,  230.        ]),
#  array([  -1.42083561,   -1.13848441,  230.        ]),
#  array([ 0.,  0.,  0.]),
#  array([ -4.21054870e-01,   7.34821892e-02,   2.30000000e+02]),
# ...
